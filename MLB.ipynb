# %%
import streamlit as st
from pybaseball import standings
from pybaseball import schedule_and_record
import pandas as pd

@st.cache_resource
def load_data():
    data = standings(2026)
    return data

data = load_data()

# %%
options = ["AL East", "AL Central", "AL West",
     "NL East", "NL Central", "NL West"]

selection = st.selectbox("Label", options)

mapping = {
    "AL East" : 0,
    "AL Central" : 1,
    "AL West" : 2,
    "NL East" : 3,
    "NL Central" : 4,
    "NL West" : 5,
}

indexing_var = mapping[selection]

df = data[indexing_var]

st.dataframe(df)
# Out:
# 2026-04-16 11:52:30.893 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:30.894 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:30.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:30.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:30.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:30.900 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:30.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:30.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:30.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:30.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
options = [
    "Arizona Diamondbacks", 
    "__ Athletics",
    "Atlanta Braves",
    "Baltimore Orioles",
    "Boston Red Sox",
    "Chicago Cubs",
    "Chicago White Sox",
    "Cincinnati Reds",
    "Cleveland Guardians",
    "Colorado Rockies",
    "Detroit Tigers",
    "Houston Astros",
    "Kansas City Royals",
    "Los Angeles Angels",
    "Los Angeles Dodgers",
    "Miami Marlins",
    "Milwaukee Brewers",
    "Minnesota Twins",
    "New York Mets",
    "New York Yankees",
    "Philadelphia Phillies",
    "Pittsburgh Pirates",
    "San Diego Padres",
    "San Francisco Giants",
    "Seattle Mariners",
    "St. Louis Cardinals",
    "Tampa Bay Rays",
    "Texas Rangers",
    "Toronto Blue Jays",
    "Washington Nationals"
    ]

selection = st.selectbox("Choose Your Team!", options)

mapping = {
    "Arizona Diamondbacks" : "ARI", 
    "__ Athletics" : "ATH",
    "Atlanta Braves" : "ATL",
    "Baltimore Orioles" : "BAL",
    "Boston Red Sox" : "BOS",
    "Chicago Cubs" : "CHC",
    "Chicago White Sox" : "CHW",
    "Cincinnati Reds" : "CIN",
    "Cleveland Guardians" : "CLE",
    "Colorado Rockies" : "COL",
    "Detroit Tigers" : "DET",
    "Houston Astros" : "HOU",
    "Kansas City Royals" : "KCR",
    "Los Angeles Angels" : "LAA",
    "Los Angeles Dodgers" : "LAD",
    "Miami Marlins" : "MIA",
    "Milwaukee Brewers" : "MIL",
    "Minnesota Twins" : "MIN",
    "New York Mets" : "NYM",
    "New York Yankees" : "NYY",
    "Philadelphia Phillies" : "PHI",
    "Pittsburgh Pirates" : "PIT",
    "San Diego Padres" : "SDP",
    "San Francisco Giants" : "SFG",
    "Seattle Mariners": "SEA",
    "St. Louis Cardinals" : "STL",
    "Tampa Bay Rays" : "TBR",
    "Texas Rangers" : "TEX",
    "Toronto Blue Jays" : "TOR",
    "Washington Nationals" : "WSN"
}

indexing_var = mapping[selection]

df = pd.DataFrame(schedule_and_record(2026, indexing_var))

st.dataframe(df)
# Out:
# 2026-04-16 11:52:33.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:33.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:33.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:33.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:33.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:33.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:33.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# http://www.baseball-reference.com/teams/ARI/2026-schedule-scores.shtml
# c:\Josh's Folder\Statistics Hobby\PGA Tour\.venv\Lib\site-packages\pybaseball\team_results.py:75: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# 2026-04-16 11:52:33.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:33.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-16 11:52:33.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
hi = schedule_and_record(2026, "ARI")
hi
# Out:
# http://www.baseball-reference.com/teams/ARI/2026-schedule-scores.shtml
# c:\Josh's Folder\Statistics Hobby\PGA Tour\.venv\Lib\site-packages\pybaseball\team_results.py:75: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
#                   Date   Tm Home_Away  Opp  W/L    R   RA  Inn  W-L  Rank  \
# 1     Thursday, Mar 26  ARI         @  LAD    L  2.0  8.0  9.0  0-1   3.0
# 2       Friday, Mar 27  ARI         @  LAD    L  4.0  5.0  9.0  0-2   3.0
# 3     Saturday, Mar 28  ARI         @  LAD    L  2.0  3.0  9.0  0-3   4.0
# 4       Monday, Mar 30  ARI      Home  DET    W  9.0  6.0  9.0  1-3   2.0
# 5      Tuesday, Mar 31  ARI      Home  DET    W  7.0  5.0  9.0  2-3   2.0
# ..                 ...  ...       ...  ...  ...  ...  ...  ...  ...   ...
# 157    Tuesday, Sep 22  ARI         @  COL  NaN  NaN  NaN  NaN  NaN   NaN
# 158  Wednesday, Sep 23  ARI         @  COL  NaN  NaN  NaN  NaN  NaN   NaN
# 159   Thursday, Sep 24  ARI         @  COL  NaN  NaN  NaN  NaN  NaN   NaN
# 160     Friday, Sep 25  ARI         @  SDP  NaN  NaN  NaN  NaN  NaN   NaN
# 161   Saturday, Sep 26  ARI         @  SDP  NaN  NaN  NaN  NaN  NaN   NaN
#
#       GB        Win       Loss    Save  Time  D/N  Attendance   cLI  Streak  \
# 1    1.0   Yamamoto     Gallen    None  2:39    N     53712.0   .92    -1.0
# 2    2.0  Henriquez     Ginkel    Díaz  2:51    N     51540.0   .92    -2.0
# 3    3.0      Klein    Morillo    Díaz  2:30    N     53340.0  1.21    -3.0
# 4    2.0     Soroka  Verlander  Sewald  3:07    N     48350.0   .99     1.0
# 5    2.0   Hoffmann       Vest  Sewald  2:29    N     28780.0   .95     2.0
# ..   ...        ...        ...     ...   ...  ...         ...   ...     ...
# 157  NaN        NaN        NaN     NaN   NaN  NaN         NaN   NaN     NaN
# 158  NaN        NaN        NaN     NaN   NaN  NaN         NaN   NaN     NaN
# 159  NaN        NaN        NaN     NaN   NaN  NaN         NaN   NaN     NaN
# 160  NaN        NaN        NaN     NaN   NaN  NaN         NaN   NaN     NaN
# 161  NaN        NaN        NaN     NaN   NaN  NaN         NaN   NaN     NaN
#
#     Orig. Scheduled
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# ..              ...
# 157             NaN
# 158             NaN
# 159             NaN
# 160             NaN
# 161             NaN
#
# [161 rows x 20 columns]
